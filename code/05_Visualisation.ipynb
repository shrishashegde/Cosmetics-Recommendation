# %%
# import libraries
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

from bokeh.io import show, curdoc, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, Select, Paragraph, TextInput
from bokeh.layouts import widgetbox, column, row
from ipywidgets import interact

# %%
df = pd.read_csv('../data/cosmetic_TSNE.csv')
df.head()
# Out:
#                      Label                                               Name  \
# 0  moisturizer_Combination  Revealer Skin-Improving Foundation SPF25 with ...
# 1  moisturizer_Combination             Plum Plump Hyaluronic Acid Moisturizer
# 2  moisturizer_Combination  The Water Cream Oil-Free Pore Minimizing Moist...
# 3  moisturizer_Combination     Vitamin Enriched Face Base Priming Moisturizer
# 4  moisturizer_Combination              Ultra Repair® Cream Intense Hydration
#
#               brand  price  rank  \
# 0             Kosas     42   4.0
# 1       Glow Recipe     39   4.5
# 2            Tatcha     69   4.0
# 3       Bobbi Brown     64   4.5
# 4  First Aid Beauty     38   4.5
#
#                                          ingredients  Combination  Dry  \
# 0  Zinc Oxide (7.5%), Water, Ethylhexyl Olivate, ...            1    1
# 1  Water/Aqua/Eau, Propanediol, Glycerin, C13-15 ...            1    1
# 2  Water, Saccharomyces/Camellia Sinensis Leaf/Cl...            1    1
# 3  Water, Cyclopentasiloxane, Bis-Diglyceryl Poly...            1    0
# 4  Colloidal Oatmeal 0.50%, Water, Stearic Acid, ...            1    1
#
#    Normal  Oil         X         Y
# 0       1    1  1.377293 -2.710624
# 1       1    1  4.284342 -3.638289
# 2       1    1  1.072965 -4.175159
# 3       1    1 -1.305105  1.498212
# 4       1    0  2.768894 -5.801363

# %%
df.Label.unique()
# Out:
# array(['moisturizer_Combination', 'moisturizer_Dry', 'moisturizer_Normal',
#        'moisturizer_Oil', 'cleanser_Combination', 'cleanser_Dry',
#        'cleanser_Normal', 'cleanser_Oil', 'face_treatment_Combination',
#        'face_treatment_Dry', 'face_treatment_Normal',
#        'face_treatment_Oil', 'face_mask_Combination', 'face_mask_Dry',
#        'face_mask_Normal', 'face_mask_Oil', 'eye_treatment_Combination',
#        'eye_treatment_Dry', 'eye_treatment_Normal', 'eye_treatment_Oil',
#        'sunscreen_Combination', 'sunscreen_Dry', 'sunscreen_Normal',
#        'sunscreen_Oil'], dtype=object)

# %%
df.columns
# Out:
# Index(['Label', 'Name', 'brand', 'price', 'rank', 'ingredients', 'Combination',
#        'Dry', 'Normal', 'Oil', 'X', 'Y'],
#       dtype='object')

# %%
option_1 =['moisturizer', 'cleanser', 'face_treatment', 'face_mask', 'eye_treatment', 'sunscreen']
option_2 = ['Combination', 'Dry', 'Normal', 'Oil']

# %% [markdown]
# # Mapping with Bokeh

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# make a source and scatter bokeh plot  
source = ColumnDataSource(df)
plot = figure(x_axis_label = 'T-SNE 1', y_axis_label = 'T-SNE 2', 
              width = 500, height = 400)
plot.circle(x = 'X', y = 'Y', source = source, 
            size = 10, color = '#FF7373', alpha = .8)

plot.background_fill_color = "beige"
plot.background_fill_alpha = 0.2

# add hover tool
hover = HoverTool(tooltips = [
        ('Item', '@Name'),
        ('brand', '@brand'),
        ('Price', '$ @price'),
        ('Rank', '@rank')])
plot.add_tools(hover)

# %%
def update(op1 = option_1[0], op2 = option_2[0]):
    a_b = op1 + '_' + op2
    new_data = {
        'X' : df[df['Label'] == a_b]['X'],
        'Y' : df[df['Label'] == a_b]['Y'],
        'name' : df[df['Label'] == a_b]['Name'],
        'brand' : df[df['Label'] == a_b]['brand'],
        'price' : df[df['Label'] == a_b]['price'],
        'rank' : df[df['Label'] == a_b]['rank'],
    }
    source.data = new_data
    push_notebook()

# %%
output_notebook()

interact(update, op1 = option_1, op2 = option_2)
show(plot, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1043">Loading BokehJS ...</span>
#     </div>
# interactive(children=(Dropdown(description='op1', options=('moisturizer', 'cleanser', 'face_treatment', 'face_…
#   <div class="bk-root" id="9ce7f7c8-fbc7-462b-bb23-6986bdebdefd" data-root-id="1004"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# # Cosine similarity

# %% [markdown]
# Taking exam of Peat Miracle Revital Cream

# %%
df_2 = df.loc[df.Label == 'moisturizer_Dry'].reset_index().drop('index', axis = 1)
df_2['dist'] = 0.0
myItem = df_2[df_2.Name.str.contains('Peat Miracle Revital Cream')]
myItem
# Out:
#                Label                        Name  brand  price  rank  \
# 287  moisturizer_Dry  Peat Miracle Revital Cream  belif     58   4.5
#
#                                            ingredients  Combination  Dry  \
# 287  Water, Dipropylene Glycol, Glycerin, Caprylic/...            1    1
#
#      Normal  Oil         X         Y  dist
# 287       1    1 -0.917154 -7.641208   0.0

# %%
# getting the array for myItem
P1 = np.array([myItem.X.values, myItem.Y.values]).reshape(1, -1)

# %%
# cosine similarities with other items
for i in range(len(df_2)):
    P2 = np.array([df_2['X'][i], df_2['Y'][i]]).reshape(-1, 1)
    df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# Out:
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# ...
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))
# C:\Users\Checkout\AppData\Local\Temp/ipykernel_6900/357571605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.dist[i] = cosine_similarity(P1, P2.reshape(1,2))

# %%
df_2 = df_2.sort_values('dist', ascending=False)
df_2[['Name', 'brand', 'dist']].head(6)
# Out:
#                                                   Name            brand  \
# 287                         Peat Miracle Revital Cream            belif
# 396                     CC+ Airbrush Perfecting Powder     IT Cosmetics
# 212            Black Label Detox BB Beauty Balm SPF 30        Dr. Jart+
# 370  Bye Bye Redness Neutralizing Color-Correcting ...     IT Cosmetics
# 188                     +Retinol Vitamin C Moisturizer  Kate Somerville
# 288  NightWear Plus Anti-Oxidant Night Detox Moistu...     Estée Lauder
#
#          dist
# 287  1.000000
# 396  0.999990
# 212  0.999954
# 370  0.999944
# 188  0.999917
# 288  0.999838

# %% [markdown]
# These are the top 5 items that are similar to the product type Moisturizer with name Peat Miracle Revital Cream and skin type dry with respect to the ingredients
